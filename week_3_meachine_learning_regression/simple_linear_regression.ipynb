# %%
# Import the pandas library for data manipulation
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

# %%
dataset=pd.read_csv("/content/drive/MyDrive/HopeAI/ml_regression_dataset/Salary_Data.csv")
# Display the loaded dataset
dataset

# %%
# Split the dataset into independent variable (YearsExperience)
independent=dataset[["YearsExperience"]]
independent

# %%
# Split the dataset into dependent variable (Salary)
dependent=dataset[["Salary"]]
dependent

# %%
#splitting Traning Set and Test Set using sklearn library
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
#learning Phase
from sklearn.linear_model import LinearRegression #import LinearRegression func from sklearn.linear.model
regressor=LinearRegression() # Called Linear unparatized func and assigned to regressor variable
regressor.fit(x_train, y_train) # Call X_train, Y_ Train values using regressor.fit func

# %%
weight=regressor.coef_ #calculating weight using coef_ method
weight

# %%
bais=regressor.intercept_ #Calculate bais using intercept_ method
bais

# %%
#evaluate Phase
y_pred=regressor.predict(x_test) #getting predict value using test set

# %%
#calculate r2_score and evaluvate test set model
from sklearn.metrics import r2_score #import r2_score func from sklearn.metrics
r_score=r2_score(y_test,y_pred) # Evaluate r2 score using actual and predict value
r_score # Display the R-squared score

# %%
#Saving the Final Model
import pickle#import pickle liblrary
filename="/content/drive/MyDrive/HopeAI/ml_regression_model/finalized_model_linear.sav"# save the model as finalized_model_linear.sav file and assigned to filename

# %%
pickle.dump(regressor,open(filename,'wb'))#save the model

# %%
# Load the saved model to get final result
loaded_model=pickle.load(open(filename,'rb'))

# Create a DataFrame for prediction to avoid UserWarning about feature names
import pandas as pd
predict_input = pd.DataFrame([[13]], columns=['YearsExperience'])
result=loaded_model.predict(predict_input) # Final prediction

# %%
# Display the prediction result
result
