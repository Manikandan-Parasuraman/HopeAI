# %%
# Import the pandas library for data manipulation
import pandas as pd

# %%
import os; os.getcwd()
from pathlib import Path; Path(r"week_3_meachine_learning_regression\dataset\Salary_Data.csv").exists()
# Out:
# False
